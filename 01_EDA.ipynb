# %%
# """
# Environment Configuration
# ------------------------
# This notebook sets up the development environment, including:
# - Environment type (local vs. Colab)
# - GitHub repository configuration
# - Google Drive data directory mounting
# - Device configuration (CPU/GPU)
# """

# # Core environment constants
# ENVIRONMENT = 'colab'
# BRANCH_NAME = 'main'
# REPOSITORY_OWNER = 'tristan-day-research'
# REPOSITORY = 'CIBMTR_cancer_outcome_predictions'
# GOOGLE_DRIVE_DIR = 'CIBMTR_data'

# # Configure environment based on runtime type
# if ENVIRONMENT == 'colab':
#     from google.colab import userdata

#     # Start from the content directory
#     %cd /content

#     # Get GitHub token and clone repository
#     token = userdata.get('GITHUB_PAT')
#     !git clone -b {BRANCH_NAME} https://{token}@github.com/{REPOSITORY_OWNER}/{REPOSITORY}.git

#     # Change to repository directory
#     %cd {REPOSITORY}

#     # Import and run environment setup
#     from src import setup
#     env_config = setup.configure_environment(
#         environment=ENVIRONMENT,
#         google_drive_dir=GOOGLE_DRIVE_DIR
#     )

# # Set commonly used configuration values for easier access
# data_path = env_config.data_dir
# device = env_config.device

# Core environment constants
ENVIRONMENT = 'colab'
BRANCH_NAME = 'main'
REPOSITORY_OWNER = 'tristan-day-research'
REPOSITORY = 'CIBMTR_cancer_outcome_predictions'
GOOGLE_DRIVE_DIR = 'CIBMTR_data'

# Configure environment based on runtime type
if ENVIRONMENT == 'colab':
    from google.colab import userdata
    import os

    # Set repository name as environment variable for notebook setup
    os.environ['REPOSITORY'] = REPOSITORY

    # Start from the content directory
    # %cd /content

    # Get GitHub token and clone repository
    token = userdata.get('GITHUB_PAT')
    # !git clone -b {BRANCH_NAME} https://{token}@github.com/{REPOSITORY_OWNER}/{REPOSITORY}.git

    # Change to repository directory
    # %cd {REPOSITORY}

    # Import and run environment setup
    from src import setup
    env_config = setup.configure_environment(
        environment=ENVIRONMENT,
        google_drive_dir=GOOGLE_DRIVE_DIR
    )

# Set commonly used configuration values for easier access
data_path = env_config.data_dir
device = env_config.device
# Out:
# /content
# Cloning into 'CIBMTR_cancer_outcome_predictions'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 131 (delta 45), reused 98 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (131/131), 98.83 KiB | 2.25 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/CIBMTR_cancer_outcome_predictions
# Mounted at /content/drive
# WARNING:src.setup:GPU not available, falling back to CPU
# WARNING:src.setup:GCP configuration not available: Secret GCP_BUCKET_NAME does not exist.

# %% [markdown]
# # Load Data

# %%
import pandas as pd

# Load data into variables
data_dict_df = pd.read_csv(f'{data_path}/data_dictionary.csv')
sample_submission_df = pd.read_csv(f'{data_path}/sample_submission.csv')
test_df = pd.read_csv(f'{data_path}/test.csv')
train_df = pd.read_csv(f'{data_path}/train.csv')

# %% [markdown]
# # EDA

# %%
# # Get all categorical (object type) columns
# categorical_columns = train_df.select_dtypes(include=['object']).columns

# print('Categorical Variable Distributions:\n')
# for col in categorical_columns:
#     print(f'\n{col} Distribution:')
#     print(train_df[col].value_counts(normalize=True).mul(100).round(1))
#     print(f'Missing values: {train_df[col].isnull().sum()}')
#     print('-' * 50)
# Out:
# Categorical Variable Distributions:
#
#
# dri_score Distribution:
# dri_score
# Intermediate                                         36.4
# N/A - pediatric                                      16.7
# High                                                 16.4
# N/A - non-malignant indication                        8.5
# TBD cytogenetics                                      7.0
# Low                                                   6.7
# High - TED AML case <missing cytogenetics             4.9
# Intermediate - TED AML case <missing cytogenetics     1.7
# N/A - disease not classifiable                        0.9
# Very high                                             0.7
# Missing disease status                                0.0
# Name: proportion, dtype: float64
# Missing values: 154
# --------------------------------------------------
#
# psych_disturb Distribution:
# psych_disturb
# No          86.0
# Yes         13.4
# Not done     0.5
# Name: proportion, dtype: float64
# Missing values: 2062
# --------------------------------------------------
#
# cyto_score Distribution:
# cyto_score
# Poor            42.5
# Intermediate    30.8
# Favorable       14.5
# TBD              6.5
# Normal           3.1
# Other            2.4
# Not tested       0.3
# Name: proportion, dtype: float64
# Missing values: 8068
# --------------------------------------------------
#
# diabetes Distribution:
# diabetes
# No          83.2
# Yes         16.3
# Not done     0.5
# Name: proportion, dtype: float64
# Missing values: 2119
# --------------------------------------------------
#
# tbi_status Distribution:
# tbi_status
# No TBI                              65.5
# TBI + Cy +- Other                   21.2
# TBI +- Other, <=cGy                  6.0
# TBI +- Other, >cGy                   5.9
# TBI +- Other, -cGy, single           0.5
# TBI +- Other, -cGy, fractionated     0.4
# TBI +- Other, -cGy, unknown dose     0.3
# TBI +- Other, unknown dose           0.3
# Name: proportion, dtype: float64
# Missing values: 0
# --------------------------------------------------
#
# arrhythmia Distribution:
# arrhythmia
# No          94.8
# Yes          4.8
# Not done     0.4
# Name: proportion, dtype: float64
# Missing values: 2202
# --------------------------------------------------
#
# graft_type Distribution:
# graft_type
# Peripheral blood    71.3
# Bone marrow         28.7
# Name: proportion, dtype: float64
# Missing values: 0
# --------------------------------------------------
#
# vent_hist Distribution:
# vent_hist
# No     97.1
# Yes     2.9
# Name: proportion, dtype: float64
# Missing values: 259
# --------------------------------------------------
#
# renal_issue Distribution:
# renal_issue
# No          98.7
# Yes          0.7
# Not done     0.5
# Name: proportion, dtype: float64
# Missing values: 1915
# --------------------------------------------------
#
# pulm_severe Distribution:
# pulm_severe
# No          92.9
# Yes          6.4
# Not done     0.7
# Name: proportion, dtype: float64
# Missing values: 2135
# --------------------------------------------------
#
# prim_disease_hct Distribution:
# prim_disease_hct
# ALL                     28.1
# AML                     24.8
# MDS                     10.6
# IPA                      6.0
# MPN                      5.8
# IEA                      5.0
# NHL                      4.6
# IIS                      3.6
# PCD                      3.0
# SAA                      2.5
# AI                       1.6
# HIS                      1.5
# Other leukemia           1.3
# Solid tumor              0.7
# IMD                      0.5
# Other acute leukemia     0.3
# HD                       0.2
# CML                      0.1
# Name: proportion, dtype: float64
# Missing values: 0
# --------------------------------------------------
#
# cmv_status Distribution:
# cmv_status
# +/+    48.3
# -/+    25.1
# +/-    14.4
# -/-    12.2
# Name: proportion, dtype: float64
# Missing values: 634
# --------------------------------------------------
#
# tce_imm_match Distribution:
# tce_imm_match
# P/P    74.2
# G/G    14.3
# H/H     6.1
# G/B     3.1
# H/B     1.3
# P/H     0.5
# P/B     0.4
# P/G     0.1
# Name: proportion, dtype: float64
# Missing values: 11133
# --------------------------------------------------
#
# rituximab Distribution:
# rituximab
# No     97.7
# Yes     2.3
# Name: proportion, dtype: float64
# Missing values: 2148
# --------------------------------------------------
#
# prod_type Distribution:
# prod_type
# PB    70.8
# BM    29.2
# Name: proportion, dtype: float64
# Missing values: 0
# --------------------------------------------------
#
# cyto_score_detail Distribution:
# cyto_score_detail
# Intermediate    66.1
# Poor            19.7
# Favorable        7.2
# TBD              6.2
# Not tested       0.9
# Name: proportion, dtype: float64
# Missing values: 11923
# --------------------------------------------------
#
# conditioning_intensity Distribution:
# conditioning_intensity
# MAC                              51.2
# RIC                              32.2
# NMA                              14.5
# TBD                               1.6
# No drugs reported                 0.4
# N/A, F(pre-TED) not submitted     0.3
# Name: proportion, dtype: float64
# Missing values: 4789
# --------------------------------------------------
#
# ethnicity Distribution:
# ethnicity
# Not Hispanic or Latino      86.8
# Hispanic or Latino          11.9
# Non-resident of the U.S.     1.4
# Name: proportion, dtype: float64
# Missing values: 587
# --------------------------------------------------
#
# obesity Distribution:
# obesity
# No          93.0
# Yes          6.6
# Not done     0.4
# Name: proportion, dtype: float64
# Missing values: 1760
# --------------------------------------------------
#
# mrd_hct Distribution:
# mrd_hct
# Negative    66.1
# Positive    33.9
# Name: proportion, dtype: float64
# Missing values: 16597
# --------------------------------------------------
#
# in_vivo_tcd Distribution:
# in_vivo_tcd
# No     61.6
# Yes    38.4
# Name: proportion, dtype: float64
# Missing values: 225
# --------------------------------------------------
#
# tce_match Distribution:
# tce_match
# Permissive            64.0
# GvH non-permissive    16.4
# Fully matched         10.8
# HvG non-permissive     8.9
# Name: proportion, dtype: float64
# Missing values: 18996
# --------------------------------------------------
#
# hepatic_severe Distribution:
# hepatic_severe
# No          93.7
# Yes          5.5
# Not done     0.8
# Name: proportion, dtype: float64
# Missing values: 1871
# --------------------------------------------------
#
# prior_tumor Distribution:
# prior_tumor
# No          87.9
# Yes         11.1
# Not done     1.1
# Name: proportion, dtype: float64
# Missing values: 1678
# --------------------------------------------------
#
# peptic_ulcer Distribution:
# peptic_ulcer
# No          98.4
# Yes          1.0
# Not done     0.6
# Name: proportion, dtype: float64
# Missing values: 2419
# --------------------------------------------------
#
# gvhd_proph Distribution:
# gvhd_proph
# FK+ MMF +- others                  36.5
# Cyclophosphamide alone             18.4
# FK+ MTX +- others(not MMF)         14.9
# Cyclophosphamide +- others          8.3
# CSA + MMF +- others(not FK)         8.0
# FKalone                             4.3
# Other GVHD Prophylaxis              1.9
# TDEPLETION alone                    1.9
# TDEPLETION +- other                 1.9
# No GvHD Prophylaxis                 0.9
# CDselect alone                      0.9
# CSA + MTX +- others(not MMF,FK)     0.8
# CSA alone                           0.7
# Parent Q = yes, but no agent        0.2
# CDselect +- other                   0.2
# CSA +- others(not FK,MMF,MTX)       0.1
# FK+- others(not MMF,MTX)            0.0
# Name: proportion, dtype: float64
# Missing values: 225
# --------------------------------------------------
#
# rheum_issue Distribution:
# rheum_issue
# No          97.7
# Yes          1.7
# Not done     0.5
# Name: proportion, dtype: float64
# Missing values: 2183
# --------------------------------------------------
#
# sex_match Distribution:
# sex_match
# M-M    28.0
# F-M    27.4
# M-F    23.5
# F-F    21.1
# Name: proportion, dtype: float64
# Missing values: 261
# --------------------------------------------------
#
# race_group Distribution:
# race_group
# More than one race                           16.8
# Asian                                        16.8
# White                                        16.8
# Black or African-American                    16.6
# American Indian or Alaska Native             16.6
# Native Hawaiian or other Pacific Islander    16.3
# Name: proportion, dtype: float64
# Missing values: 0
# --------------------------------------------------
#
# hepatic_mild Distribution:
# hepatic_mild
# No          93.0
# Yes          6.5
# Not done     0.5
# Name: proportion, dtype: float64
# Missing values: 1917
# --------------------------------------------------
#
# tce_div_match Distribution:
# tce_div_match
# Permissive mismatched            74.3
# GvH non-permissive               14.1
# HvG non-permissive                8.1
# Bi-directional non-permissive     3.4
# Name: proportion, dtype: float64
# Missing values: 11396
# --------------------------------------------------
#
# donor_related Distribution:
# donor_related
# Related                     56.6
# Unrelated                   42.2
# Multiple donor (non-UCB)     1.2
# Name: proportion, dtype: float64
# Missing values: 158
# --------------------------------------------------
#
# melphalan_dose Distribution:
# melphalan_dose
# N/A, Mel not given    73.5
# MEL                   26.5
# Name: proportion, dtype: float64
# Missing values: 1405
# --------------------------------------------------
#
# cardiac Distribution:
# cardiac
# No          93.7
# Yes          5.8
# Not done     0.6
# Name: proportion, dtype: float64
# Missing values: 2542
# --------------------------------------------------
#
# pulm_moderate Distribution:
# pulm_moderate
# No          79.8
# Yes         19.6
# Not done     0.6
# Name: proportion, dtype: float64
# Missing values: 2047
# --------------------------------------------------

# %%
# from src.eda import analysis
# import importlib
# importlib.reload(analysis)  # Note: reload analysis, not eda

# output_dir='results/EDA'

# # analysis.comprehensive_eda(train_df)
# # analysis.initial_data_overview(train_df, output_dir)
# analysis.analyze_categorical_distributions(train_df, output_dir)

# %% [markdown]
# # Analyze missing values in data

# %%
csv_name = '/content/CIBMTR_cancer_outcome_predictions/results/EDA/missing_values.csv'

df = pd.read_csv(csv_name)
df = df.sort_values('Missing Percentage', ascending=False)  # Sort by specific column

df.to_csv(csv_name)

# %%
from src.eda import missing_values
import importlib
importlib.reload(missing_values)  # Note: reload analysis, not eda

output_dir='results/EDA'

missing_values.analyze_missing_patterns(train_df, output_dir)

# %%
from src.eda import missing_values
import importlib
importlib.reload(missing_values)  # Note: reload analysis, not eda

output_dir='results/EDA/missing_value_analysis'

# column = 'hla_high_res_10'
# group_col='race_group'

# # missing_values.chi_square_missing_by_group(train_df, column, group_col)
# missing_values.chi_square_missing_by_group(train_df, column, group_col)

group_variable = 'race_group'

# These are the top features with missing values
features_to_analyze = [
   'tce_match',
   'mrd_hct',
   'cyto_score_detail',
   'tce_div_match',
   'tce_imm_match',
   'cyto_score',
   'hla_high_res_10',
   'hla_high_res_8',
   'hla_high_res_6',
   'hla_match_dqb1_high',
   'hla_low_res_10',
   'conditioning_intensity',
   'hla_match_c_high',
   'hla_match_a_high',
   'hla_nmdp_6',
   'hla_match_dqb1_low',
   'hla_match_b_high',
   'hla_low_res_8',
   'hla_match_drb1_high',
   'hla_low_res_6'
]

missing_values.analyze_group_differences(train_df, group_variable, features_to_analyze, output_dir=output_dir)
missing_values.visualize_group_differences(train_df, group_variable, features_to_analyze, output_dir=output_dir)
# Out:
# results/EDA/missing_value_analysis
# tce_match 6.065719569121874e-210
# mrd_hct 0.0002647971673972512
# cyto_score_detail 2.9912561827733095e-120
# tce_div_match 5.896528378111704e-136
# tce_imm_match 3.805168518693835e-125
# cyto_score 5.874445800410101e-106
# hla_high_res_10 1.2124063947067201e-116
# hla_high_res_8 1.1159005098018191e-115
# hla_high_res_6 1.5502003070922266e-108
# hla_match_dqb1_high 7.856720449187174e-87
# hla_low_res_10 7.35009191602592e-95
# conditioning_intensity 1.848001895532784e-134
# hla_match_c_high 7.277356179002075e-96
# hla_match_a_high 3.186738434882811e-86
# hla_nmdp_6 1.972605617354519e-99
# hla_match_dqb1_low 1.561837255536488e-71
# hla_match_b_high 8.487693085539501e-85
# hla_low_res_8 3.151605189171145e-88
# hla_match_drb1_high 3.9244589933749467e-88
# hla_low_res_6 2.4216314608639876e-86
# /content/CIBMTR_cancer_outcome_predictions/src/eda/missing_values.py:103: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.xlabel('Maximum Difference Between Groups')
# /content/CIBMTR_cancer_outcome_predictions/src/eda/missing_values.py:104: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.ylabel('-log10(p-value)')
